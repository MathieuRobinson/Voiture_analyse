# %%
import pandas as pd

# %%
chemin='Automobile.csv'

# %%
df=pd.read_csv(chemin)

# %%
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
len(df)
# Out:
# 398

# %%
df_new=df.copy()

# %%
df_new=df_new.drop('displacement',axis=1)

# %%
df_new
# Out:
#                           name   mpg  cylinders  horsepower  weight  \
# 0    chevrolet chevelle malibu  18.0          8       130.0    3504
# 1            buick skylark 320  15.0          8       165.0    3693
# 2           plymouth satellite  18.0          8       150.0    3436
# 3                amc rebel sst  16.0          8       150.0    3433
# 4                  ford torino  17.0          8       140.0    3449
# ..                         ...   ...        ...         ...     ...
# 393            ford mustang gl  27.0          4        86.0    2790
# 394                  vw pickup  44.0          4        52.0    2130
# 395              dodge rampage  32.0          4        84.0    2295
# 396                ford ranger  28.0          4        79.0    2625
# 397                 chevy s-10  31.0          4        82.0    2720
#
#      acceleration  model_year  origin
# 0            12.0          70     usa
# 1            11.5          70     usa
# ...

# %%
fort_horse_power=df_new.sort_values('horsepower',ascending=False).iloc[:5]

# %%
fort_horse_power
# Out:
#                                 name   mpg  cylinders  horsepower  weight  \
# 19      volkswagen 1131 deluxe sedan  26.0          4        46.0    1835
# 102          volkswagen super beetle  26.0          4        46.0    1950
# 326               vw dasher (diesel)  43.4          4        48.0    2335
# 325             vw rabbit c (diesel)  44.3          4        48.0    2085
# 244  volkswagen rabbit custom diesel  43.1          4        48.0    1985
#
#      acceleration  model_year  origin
# 19           20.5          70  europe
# 102          21.0          73  europe
# 326          23.7          80  europe
# 325          21.7          80  europe
# 244          21.5          78  europe

# %%
fort_acceleration=df_new.sort_values('acceleration',ascending=False).iloc[:5]

# %%
fort_acceleration
# Out:
#                                   name   mpg  cylinders  horsepower  weight  \
# 299                        peugeot 504  27.2          4        71.0    3190
# 394                          vw pickup  44.0          4        52.0    2130
# 326                 vw dasher (diesel)  43.4          4        48.0    2335
# 59                   volkswagen type 3  23.0          4        54.0    2254
# 300  oldsmobile cutlass salon brougham  23.9          8        90.0    3420
#
#      acceleration  model_year  origin
# 299          24.8          79  europe
# 394          24.6          82  europe
# 326          23.7          80  europe
# 59           23.5          72  europe
# 300          22.2          79     usa

# %%
df_new['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
faible_consommation=df_new.sort_values('mpg',ascending=True).iloc[:1]

# %%
faible_consommation
# Out:
#         name  mpg  cylinders  horsepower  weight  acceleration  model_year  \
# 28  hi 1200d  9.0          8       193.0    4732          18.5          70
#
#    origin
# 28    usa

# %%
poids=df_new.sort_values('weight',ascending=True).iloc[:1]

# %%
poids
# Out:
#            name   mpg  cylinders  horsepower  weight  acceleration  \
# 54  datsun 1200  35.0          4        69.0    1613          18.0
#
#     model_year origin
# 54          71  japan

# %%
moyenne_puissance=df_new['horsepower'].mean()

# %%
moyenne_puissance
# Out:
# 104.46938775510205

# %%
new_region=df_new.set_index('origin')

# %%
new_region
# Out:
#                              name   mpg  cylinders  horsepower  weight  \
# origin
# usa     chevrolet chevelle malibu  18.0          8       130.0    3504
# usa             buick skylark 320  15.0          8       165.0    3693
# usa            plymouth satellite  18.0          8       150.0    3436
# usa                 amc rebel sst  16.0          8       150.0    3433
# usa                   ford torino  17.0          8       140.0    3449
# ...                           ...   ...        ...         ...     ...
# usa               ford mustang gl  27.0          4        86.0    2790
# europe                  vw pickup  44.0          4        52.0    2130
# usa                 dodge rampage  32.0          4        84.0    2295
# usa                   ford ranger  28.0          4        79.0    2625
# usa                    chevy s-10  31.0          4        82.0    2720
#
#         acceleration  model_year
# origin
# usa             12.0          70
# ...

# %%
new_usa=new_region.loc['usa'][['name','horsepower','acceleration']].max()

# %%
moy_usa=new_region.loc['usa']['horsepower'].mean()

# %%
moy_usa
# Out:
# 119.04897959183674

# %%
new_usa
# Out:
# name            pontiac ventura sj
# horsepower                   230.0
# acceleration                  22.2
# dtype: object

# %%
new_japon=new_region.loc['japan'][['name','horsepower','acceleration']].max()

# %%
moy_japon=new_region.loc['japan']['horsepower'].mean()

# %%
moy_japon
# Out:
# 79.83544303797468

# %%
new_japon
# Out:
# name            toyouta corona mark ii (sw)
# horsepower                            132.0
# acceleration                           21.0
# dtype: object

# %%
new_europe=new_region.loc['europe'][['name','horsepower','acceleration']].max()

# %%
moy_europe=new_region.loc['europe']['horsepower'].mean()

# %%
moy_europe
# Out:
# 80.55882352941177

# %%
new_europe
# Out:
# name            vw rabbit custom
# horsepower                 133.0
# acceleration                24.8
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig=plt.figure(figsize=(12,4),dpi=300)
sns.scatterplot(x='horsepower',y='acceleration',data=df_new,hue='origin',s=60,style='origin')
plt.title("Diagramme de dispersion de l'horsepower et de l'acceleration",fontweight='heavy',color='blue')
plt.show()

# %%
cylindre_europe=new_region.loc['europe'][['cylinders','model_year']]

# %%
cylindre_europe
# Out:
#         cylinders  model_year
# origin
# europe          4          70
# europe          4          70
# europe          4          70
# europe          4          70
# europe          4          70
# ...           ...         ...
# europe          4          81
# europe          4          81
# europe          6          81
# europe          4          82
# europe          4          82
#
# [70 rows x 2 columns]

# %%
cylindre_japan=new_region.loc['japan'][['cylinders','model_year']]

# %%
# Creation de la figure 
plt.figure(figsize=(9,5),dpi=150)
sns.set(style='darkgrid')
sns.barplot(x = "model_year", y = "cylinders", data = cylindre_europe, palette='plasma')
plt.xticks(rotation = 60)
plt.ylabel("Cylinders",color='Blue')
plt.xlabel("Year",color='Red')
plt.title('Modele par annee des cylinders (EUROPE)')
# Out:
# Text(0.5, 1.0, 'Modele par annee des cylinders (EUROPE)')

# %%
# Creation de la figure 
plt.figure(figsize=(8,5),dpi=150)
sns.barplot(x = "model_year", y = "cylinders", data = cylindre_japan, palette='Dark2')
plt.xticks(rotation = 60)
plt.ylabel("Cylinders",color='Blue')
plt.xlabel(" Year",color='Red')
plt.title('Modele par annee des cylinders (JAPAN)')
# Out:
# Text(0.5, 1.0, 'Modele par annee des cylinders (JAPAN)')

# %%
cylindre_usa=new_region.loc['usa'][['cylinders','model_year']]

# %%
# Creation de la figure 
plt.figure(figsize=(8,5),dpi=150)
sns.barplot(x = "model_year", y = "cylinders", data = cylindre_usa, palette='dark')
plt.xticks(rotation = 60)
plt.ylabel("Cylinders",color='Blue')
plt.xlabel(" Year",color='Red')
plt.title('Modele par annee des cylinders (USA)')
# Out:
# Text(0.5, 1.0, 'Modele par annee des cylinders (USA)')

# %%
new_region
# Out:
#                              name   mpg  cylinders  horsepower  weight  \
# origin
# usa     chevrolet chevelle malibu  18.0          8       130.0    3504
# usa             buick skylark 320  15.0          8       165.0    3693
# usa            plymouth satellite  18.0          8       150.0    3436
# usa                 amc rebel sst  16.0          8       150.0    3433
# usa                   ford torino  17.0          8       140.0    3449
# ...                           ...   ...        ...         ...     ...
# usa               ford mustang gl  27.0          4        86.0    2790
# europe                  vw pickup  44.0          4        52.0    2130
# usa                 dodge rampage  32.0          4        84.0    2295
# usa                   ford ranger  28.0          4        79.0    2625
# usa                    chevy s-10  31.0          4        82.0    2720
#
#         acceleration  model_year
# origin
# usa             12.0          70
# ...

# %%
new_region=new_region['name']

# %%
new_region
# Out:
# origin
# usa       chevrolet chevelle malibu
# usa               buick skylark 320
# usa              plymouth satellite
# usa                   amc rebel sst
# usa                     ford torino
#                     ...
# usa                 ford mustang gl
# europe                    vw pickup
# usa                   dodge rampage
# usa                     ford ranger
# usa                      chevy s-10
# Name: name, Length: 398, dtype: object

# %%
usa=len(new_region['usa'])
usa
# Out:
# 249

# %%
japan=len(new_region['japan'])
japan
# Out:
# 79

# %%
europe=len(new_region['europe'])
europe
# Out:
# 70

# %%
dict = {
    "Pays" : ["USA", "EUROPE", "JAPAN" ],
    "Nbre" : [249, 79, 70],
    
}

df_dict = pd.DataFrame(dict)
df_dict
# Out:
#      Pays  Nbre
# 0     USA   249
# 1  EUROPE    79
# 2   JAPAN    70

# %%
plt.figure(figsize=(8, 6))

sns.set_palette("Set3")  # Définir la palette de couleurs
plt.pie(x = df_dict["Nbre"], labels = df_dict["Pays"], autopct="%1.1f%%", startangle=45)
# Ajouter un titre
plt.title('Taux de fabrication des voitures',fontweight='heavy')

# Afficher le diagramme
# Assure que le diagramme est un cercle
plt.axis('equal')
# Out:
# (-1.0999993375352164,
#  1.0999965619800776,
#  -1.0999999231096003,
#  1.0999983865164538)

# %%
df['acceleration'].max()
# Out:
# 24.8
